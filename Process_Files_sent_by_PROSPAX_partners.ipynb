# %%
import pandas as pd

# %% [markdown]
# # TUBINGEN
# For Tübingen, extract all unique hgvs/vcf and annotate with VEP to get hgvs/vcf

# %% [markdown]
# # SACS

# %%
df_sacs = pd.read_csv("SACS/WP1/P1_SACS_raw.csv", sep="\t")

# %%
df_sacs.columns
# Out:
# Index(['Submitting institution\n(select from dropdown)', 'local subject ID',
#        'local family ID', 'PROSPAX subject ID',
#        'NGS database ID (e.g. GENESIS, GPAP, etc)',
#        'Main phenotype \n(select from dropdown)',
#        'Case solved? \n(solved SACS / solved other gene / unsure / not solved)',
#        'Variant ID \n(consecutive number)', 'Gene',
#        'Chromosome\n(genome build hg19 / GRCh37)',
#        'Position\n(use vcf format)', 'Reference allele', 'Alternative allele',
#        'Transcript\n(use reference transcript ENST00000382298.3)',
#        'cDNA change (e.g. ', 'Protein position', 'Het / Hom',
#        'Compound heterozygous with Variant ID\n(enter variant ID, 'N/A' or 'unknown')',
#        'PaxGene available?\n(yes / no / unknown)',
#        'PBMC available?\n(yes / no / unknown)',
#        'Fibroblasts available?\n(yes / no / unknown)', 'Comment'],
#       dtype='object')

# %%
d_var = df_sacs[['Variant ID \n(consecutive number)', 
       'Chromosome\n(genome build hg19 / GRCh37)',
       'Position\n(use vcf format)', 'Reference allele', 'Alternative allele',
       'Transcript\n(use reference transcript ENST00000382298.3)',
       'cDNA change (e.g. ', 'Protein position']]

# %%
d_var
# Out:
#     Variant ID \n(consecutive number)  \
# 0                                  #1
# 1                                  #2
# 2                                  #3
# 3                                  #4
# 4                                  #5
# ..                                ...
# 108                              #109
# 109                              #110
# 110                              #111
# 111                              #112
# 112                              #113
#
#      Chromosome\n(genome build hg19 / GRCh37)  Position\n(use vcf format)  \
# 0                                          13                  23914246.0
# 1                                          13                  23909431.0
# 2                                          13                  23913292.0
# 3                                          13                  23913292.0
# 4                                          13                  23910851.0
# ..                                        ...                         ...
# 108                                        13                  23932473.0
# 109                                        13                  23905042.0
# 110                                        13                  23912269.0
# 111                                        13                  23905042.0
# 112                                        13                  23912269.0
#
#     Reference allele Alternative allele  \
# 0                  C                  A
# 1                  T                  A
# 2                  G                  A
# 3                  G                  A
# 4                GGT                  G
# ..               ...                ...
# 108                C                  T
# 109                G                  A
# 110              CAT                  C
# 111                G                  A
# 112              CAT                  C
#
#     Transcript\n(use reference transcript ENST00000382298.3)  \
# 0                                    ENST00000382298.3
# 1                                    ENST00000382298.3
# 2                                    ENST00000382298.3
# 3                                    ENST00000382298.3
# 4                                    ENST00000382298.3
# ..                                                 ...
# 108                                  ENST00000382298.3
# 109                                  ENST00000382298.3
# 110                                  ENST00000382298.3
# 111                                  ENST00000382298.3
# 112                                  ENST00000382298.3
#
#     cDNA change (e.g.    Protein position
# 0            c.3769G>T       p.Gly1275Ter
# 1            c.8584A>T       p.Lys2862Ter
# 2            c.4723C>T       p.Arg1575Trp
# 3            c.4723C>T       p.Arg1575Trp
# 4       c.7162_7163del  p.Thr2388Argfs*10
# ..                 ...                ...
# 108                NaN                NaN
# 109                NaN                NaN
# 110                NaN                NaN
# 111                NaN                NaN
# 112                NaN                NaN
#
# [113 rows x 8 columns]

# %%
# get empty hgvs lines
# get empty vcf lines
import numpy as np

empty_hgvs = []
empty_vcf = []
for idx, row in d_var.iterrows():
    if np.isnan(row['Position\n(use vcf format)']):
        empty_vcf.append(row['cDNA change (e.g. '])
    elif np.isnan(row['cDNA change (e.g. ']):
        vcf = "{} {} . {} {} . . .".format(row['Chromosome\n(genome build hg19 / GRCh37)'],
                                                                    int(row['Position\n(use vcf format)']),
                                                                    row['Reference allele'],
                                                                    row['Alternative allele'])
        empty_hgvs.append(vcf)

# %%
with open("SACS/WP1/empty_vcf.txt", "w") as f:
    for h in set(empty_vcf):
        f.write(h + "\n")

# %%
with open("SACS/WP1/empty_hgvs.txt", "w") as f:
    for h in set(empty_hgvs):
        f.write(h + "\n")

# %%
from cyvcf2 import VCF

V_empty_vcf = VCF("SACS/WP1/P1_SACS_empty_VCF.vcf")
V_empty_hgvs = VCF("SACS/WP1/P1_sacs_empty_hgvs.vcf")


for v in V_empty_vcf:
    hgvs = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000382298.3"][0].split(":")[1]
    for idx, row in df_sacs.iterrows():
        if row['cDNA change (e.g. ']==hgvs:
            df_sacs.at[idx, 'Position\n(use vcf format)'] = v.POS
            df_sacs.at[idx, 'Reference allele'] = v.REF
            df_sacs.at[idx, 'Alternative allele'] = v.ALT[0]
            
            
for v in V_empty_hgvs:
    hgvs_c = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000382298.3"][0].split(":")[1]
    hgvs_p = [tr.split("|")[11] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000382298.3"][0]
    
    for idx, row in df_sacs.iterrows():
        if row['Position\n(use vcf format)']==v.POS and row['Reference allele']==v.REF and row['Alternative allele']==v.ALT[0]:
            df_sacs.at[idx, 'cDNA change (e.g. '] = hgvs_c
            df_sacs.at[idx, 'Protein position'] = hgvs_p

# %%
df_sacs.to_csv("SACS/WP1/P1_SACS_1.tsv", sep="\t", index=False)

# %%
list(df_sacs.columns)
# Out:
# Index(['Submitting institution\n(select from dropdown)', 'local subject ID',
#        'local family ID', 'PROSPAX subject ID',
#        'NGS database ID (e.g. GENESIS, GPAP, etc)',
#        'Main phenotype \n(select from dropdown)',
#        'Case solved? \n(solved SACS / solved other gene / unsure / not solved)',
#        'Variant ID \n(consecutive number)', 'Gene',
#        'Chromosome\n(genome build hg19 / GRCh37)',
#        'Position\n(use vcf format)', 'Reference allele', 'Alternative allele',
#        'Transcript\n(use reference transcript ENST00000382298.3)',
#        'cDNA change (e.g. ', 'Protein position', 'Het / Hom',
#        'Compound heterozygous with Variant ID\n(enter variant ID, 'N/A' or 'unknown')',
#        'PaxGene available?\n(yes / no / unknown)',
#        'PBMC available?\n(yes / no / unknown)',
#        'Fibroblasts available?\n(yes / no / unknown)', 'Comment',
#        'Alternate allele'],
#       dtype='object')

# %% [markdown]
# # SPG7

# %%
df_spg7 = pd.read_csv("SPG7/WP1/P1_SPG7_raw.csv", sep="\t")

df_spg7.columns
# Out:
# Index(['Submitting institution\n(select from dropdown)', 'local subject ID',
#        'local family ID', 'PROSPAX subject ID',
#        'NGS database ID (e.g. GENESIS, GPAP, etc)',
#        'Main phenotype \n(select from dropdown)',
#        'Case solved? \n(solved SPG7 / solved other gene / unsure / not solved)',
#        'Variant ID \n(consecutive number)', 'Gene',
#        'Chromosome\n(genome build hg19 / GRCh37)',
#        'Position\n(use vcf format)', 'Reference allele', 'Alternative allele',
#        'Transcript\n(use reference transcript ENST00000268704.2)',
#        'cDNA change (e.g. ', 'Protein position', 'Het / Hom',
#        'Compound heterozygous with Variant ID\n(enter variant ID, 'N/A' or 'unknown')',
#        'PaxGene available?\n(yes / no / unknown)',
#        'PBMC available?\n(yes / no / unknown)',
#        'Fibroblasts available?\n(yes / no / unknown)', 'Comment'],
#       dtype='object')

# %%
# get empty hgvs lines
# get empty vcf lines
import numpy as np

empty_hgvs = []
empty_vcf = []
for idx, row in df_spg7.iterrows():
    
    if np.isnan(row['Position\n(use vcf format)']):
        empty_vcf.append(row['cDNA change (e.g. '])

# %%
mask = df_spg7['cDNA change (e.g. '].isnull()

index_missing_hgvs = mask[mask==True].index

for index in index_missing_hgvs:
    pos = int(df_spg7.loc[index, 'Position\n(use vcf format)'])
    ref = df_spg7.loc[index, 'Reference allele']
    alt = df_spg7.loc[index, 'Alternative allele']
    
    v = "16 {} . {} {} . . .\n".format(pos, ref, alt)
    empty_hgvs.append(v)

# %%
with open("SPG7/WP1/empty_vcf.txt", "w") as f:
    for h in set(empty_vcf):
        f.write(h + "\n")

# %%
with open("SPG7/WP1/empty_hgvs.txt", "w") as f:
    for h in set(empty_hgvs):
        f.write(h.replace(".0",""))

# %%
from cyvcf2 import VCF

V_empty_vcf = VCF("SPG7/WP1/p1_spg7_empty_vcf.vcf")
V_empty_hgvs = VCF("SPG7/WP1/p1_spg7_empty_hgvs.vcf")


for v in V_empty_vcf:
    hgvs = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000268704.2"][0].split(":")[1]
    for idx, row in df_spg7.iterrows():
        if row['cDNA change (e.g. ']==hgvs:
            df_spg7.at[idx, 'Position\n(use vcf format)'] = v.POS
            df_spg7.at[idx, 'Reference allele'] = v.REF
            df_spg7.at[idx, 'Alternative allele'] = v.ALT[0]
            
            
for v in V_empty_hgvs:
    hgvs_c = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000268704.2"][0]
    hgvs_p = [tr.split("|")[11] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000268704.2"][0]
    
    for idx, row in df_spg7.iterrows():
        if row['Position\n(use vcf format)']==v.POS and row['Reference allele']==v.REF and row['Alternative allele']==v.ALT[0]:
            df_spg7.at[idx, 'cDNA change (e.g. '] = hgvs_c
            df_spg7.at[idx, 'Protein position'] = hgvs_p

# %%
df_spg7.to_csv("SPG7/WP1/P1_SPG7_1.tsv", sep="\t", index=False)

# %% [markdown]
# # PISA

# %%
import pandas as pd
from cyvcf2 import VCF

df_sacs_pisa = pd.read_csv("SACS/P4_pisa/SACS SPG7 Finale.xlsx - SACS.tsv", sep="\t")
df_spg7_pisa = pd.read_csv("SPG7/P4_pisa/SACS SPG7 Finale.xlsx - SPG7.tsv", sep="\t")


df_sacs_pisa["Diagnosis"] = df_sacs_pisa["Diagnosis"].fillna("unsure")
df_spg7_pisa["Diagnosis"] = df_spg7_pisa["Diagnosis"].fillna("unsure")
df_sacs_pisa["Transcript "]
# Out:
# 0      NM_014363.6
# 1      NM_014363.6
# 2      NM_014363.6
# 3      NM_014363.6
# 4      NM_014363.6
#           ...
# 192    NM_014363.6
# 193    NM_014363.6
# 194    NM_014363.6
# 195    NM_014363.6
# 196    NM_014363.6
# Name: Transcript , Length: 197, dtype: object

# %%
df_sacs_pisa.head()
# Out:
#    Chromosome  Position Reference Allele Sample Allele  Transcript   \
# 0          13  23907968                T             C  NM_014363.6
# 1          13  23915089                G             A  NM_014363.6
# 2          13  23928078                C             /  NM_014363.6
# 3          13  23906661               CT             /  NM_014363.6
# 4          13  23912386                G             A  NM_014363.6
#
#     Transcript Variant Protein Variant Genotype Codice Phenotype Diagnosis
# 0           c.10047A>G        p.S3349S      Het   039C       HSP    unsure
# 1            c.2926C>T         p.R976C      Het   039C       HSP    unsure
# 2        c.2094-63delG             NaN      Hom   119C       HSP    unsure
# 3   c.11353_11354delAG    p.R3785fs*24      Het  1652B       HSP      SPG7
# 4            c.5629C>T        p.R1877*      Het  1652B       HSP    unsure

# %%
df_spg7_pisa.head()
# Out:
#    Chromosome    Position Reference Allele Sample Allele   Transcript  \
# 0          16  89574945.0                G             A  NM_003119.4
# 1          16  89619523.0                C             G  NM_003119.4
# 2          16  89595897.0               TG             /  NM_003119.4
# 3          16  89592857.0                C             T  NM_003119.4
# 4          16  89598369.0                G             A  NM_003119.4
#
#   Transcript Variant Protein Variant Genotype Codice Phenotype Diagnosis
# 0           c.120G>A          p.G40G      Het   958C       HSP    unsure
# 1          c.1916C>G         p.S639C      Het   958C       HSP    unsure
# 2     c.773_774delTG     p.V258fs*30      Het   701C       HSP      SPG7
# 3           c.739C>T         p.R247*      Het   446B       HSP      SPG7
# 4          c.1045G>A         p.G349S      Het   446B       HSP    unsure

# %%
df_sacs_pisa
# Out:
# array(['NM_014363.6', 'NM_014363.9'], dtype=object)

# %%
df_spg7_pisa["Transcript"].unique()
# Out:
# array(['NM_003119.4'], dtype=object)

# %%
def get_hgvs_ref(row, tr_id):
    for i in range(len(row["Transcript "].split(";"))):
        if row["Transcript "].strip().startswith(tr_id):
            variants = row["Transcript Variant"].split(";")
            return "ENST00000382298.3:" + variants[i].strip() + "\n"
    
pisa_sacs_hgvs = []

for idx, row in df_sacs_pisa.iterrows():
    hgvs = get_hgvs_ref(row, "NM_014363")
    patient = row["Codice"]
    diagnosis = row["Diagnosis"]
    phenotype = row["Phenotype"]
    genotype  = row["Genotype"]
    
    
    
    pisa_sacs_hgvs.append(( patient, diagnosis, phenotype, genotype, hgvs))

# %%
len(pisa_sacs_hgvs)
# Out:
# 197

# %%
def get_hgvs_ref(row, tr_id):
    for i in range(len(row["Transcript"].split(";"))):
        if row["Transcript"].strip().startswith(tr_id):
            variants = row["Transcript Variant"].split(";")
            return "ENST00000268704.2:" + variants[i].strip() + "\n"
    
pisa_spg7_hgvs = []

for idx, row in df_spg7_pisa.iterrows():
    hgvs = get_hgvs_ref(row, "NM_003119")
    patient = row["Codice"]
    diagnosis = row["Diagnosis"]
    phenotype = row["Phenotype"]
    genotype  = row["Genotype"]
    
    
    
    pisa_spg7_hgvs.append(( patient, diagnosis, phenotype, genotype, hgvs))

# %%
len(pisa_spg7_hgvs)
# Out:
# 298

# %%
pisa_sacs_hgvs_c = list(set([entry[4] for entry in pisa_sacs_hgvs]))
pisa_spg7_hgvs_c = list(set([entry[4] for entry in pisa_spg7_hgvs]))

# %%
len(pisa_sacs_hgvs_c)
# Out:
# 129

# %%
len(pisa_spg7_hgvs_c)
# Out:
# 164

# %%
with open("SACS/P4_pisa/sacs_hgvs_2_vep.txt", "w") as f:
    for h in pisa_sacs_hgvs_c:
        f.write(h)
        
with open("SPG7/P4_pisa/spg7_hgvs_2_vep.txt", "w") as f:
    for h in pisa_spg7_hgvs_c:
        f.write(h)

# %%
from cyvcf2 import VCF

V_spg7_hgvs = VCF("SPG7/P4_pisa/P4_pisa_spg7_vep_v2.vcf")
V_sacs_hgvs = VCF("SACS/P4_pisa/P4_pisa_sacs_vep_v2.vcf")

# %%
pisa_sacs_hgvs[1]
# Out:
# ('039C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.2926C>T\n')

# %%
count = 0 
for line in V_sacs_hgvs:
    count+=1
    
print(count)
count2=0
for line in V_spg7_hgvs:
    count2+=1
print(count2)
# Out:
# 128
# 156

# %%
pisa_sacs_hgvs
# Out:
# [('039C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.10047A>G\n'),
#  ('039C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.2926C>T\n'),
#  ('119C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.2094-63delG\n'),
#  ('1652B', 'SPG7', 'HSP', 'Het', 'ENST00000382298.3:c.11353_11354delAG\n'),
#  ('1652B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.5629C>T\n'),
#  ('1137B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.10982C>T\n'),
#  ('1137B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.2080G>A\n'),
#  ('543C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.7354T>C\n'),
#  ('543C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.4878C>T\n'),
#  ('543C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.260-54G>C\n'),
#  ('733B', 'SPG7', 'HSP', 'Het', 'ENST00000382298.3:c.6557_6559delGTA\n'),
#  ('733B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.9508C>T\n'),
#  ('730B',
#   'unsure',
#   'HSP',
#   'Hom?',
#   'ENST00000382298.3:c.2186-622_2186-621insA\n'),
#  ('1864A', 'unsure', 'HSP', 'Hom?', 'ENST00000382298.3:c.2186-632delA\n'),
#  ('1864A', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.1878G>T\n'),
#  ('1864A', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.259+32C>T\n'),
#  ('1177B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.12738A>G\n'),
#  ('1177B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.2080G>A\n'),
#  ('1055B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.7231A>G\n'),
#  ('1055B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.2185+56T>A\n'),
#  ('546C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.9846A>G\n'),
#  ('546C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.259+28A>G\n'),
#  ('359A', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.1839G>A\n'),
#  ('359A', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.259+32C>T\n'),
#  ('38V', 'CYP2U1', 'HSP', 'Hom', 'ENST00000382298.3:c.*30_*31insA\n'),
#  ('1954V', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.6267G>A\n'),
#  ('1954V', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.4188C>T\n'),
#  ("D'E", 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.1656A>G\n'),
#  ("D'E", 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.696T>A\n'),
#  ('RZT', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.1656A>G\n'),
#  ('RZT', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.696T>A\n'),
#  ('2024X', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.*484T>C\n'),
#  ('709X', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.*484T>C\n'),
#  ('709X', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.3129A>G\n'),
#  ('1731X', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.*484T>C\n'),
#  ('1731X', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.13717A>C\n'),
#  ('1668C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.6336A>C\n'),
#  ('1668C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.6069C>T\n'),
#  ('1668C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.5502G>C\n'),
#  ('1668C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.4118C>T\n'),
#  ('1668C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.4117G>C\n'),
#  ('1668C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.2185+56T>A\n'),
#  ('090C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.1839G>A\n'),
#  ('090C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.171+13C>T\n'),
#  ('081C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.2094-25G>A\n'),
#  ('366C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.3427C>A\n'),
#  ('366C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.2094-52A>G\n'),
#  ('361C',
#   'unsure',
#   'CMT',
#   'Hom?',
#   'ENST00000382298.3:c.259+74_259+76delTTT\n'),
#  ('361C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.259+73T>G\n'),
#  ('364B', 'unsure', 'CMT', 'Hom?', 'ENST00000382298.3:c.*30_*31insA\n'),
#  ('364B', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.12395T>C\n'),
#  ('1441B', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.9846A>G\n'),
#  ('1441B', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.259+28A>G\n'),
#  ('424B', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.11617G>A\n'),
#  ('424B', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.3907T>C\n'),
#  ('1579A', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.7504C>T\n'),
#  ('1579A', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.5151dupA\n'),
#  ('2436V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12218T>C\n'),
#  ('2436V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12213A>C\n'),
#  ('2436V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12212A>T\n'),
#  ('2436V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12211G>T\n'),
#  ('2436V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12206G>A\n'),
#  ('2431V', 'PMM2', 'HA', 'Het', 'ENST00000382298.3:c.7354T>A\n'),
#  ('2431V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5473G>T\n'),
#  ('2431V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5471T>A\n'),
#  ('2431V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.2216A>G/c.4466A>G\n'),
#  ('642X', 'RARS2', 'HA', 'Het', 'ENST00000382298.3:c.8648T>A\n'),
#  ('642X', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.6393T>C ?\n'),
#  ('371Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.2988A>G\n'),
#  ('371Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.2983G>T\n'),
#  ('470V', 'SPG7', 'HA', 'Het', 'ENST00000382298.3:c.2580A>G\n'),
#  ('2449V', 'CANVAS', 'HA', 'Hom', 'ENST00000382298.3:c.7548A>G\n'),
#  ('117A', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.7149C>T\n'),
#  ('117A', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.259+32C>T\n'),
#  ('338N', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.13717A>C\n'),
#  ('338N', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.171+3A>G\n'),
#  ('180Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.4717A>T\n'),
#  ('180Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.2146C>T\n'),
#  ('180Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.1417A>G\n'),
#  ('180Z', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.605-99C>T\n'),
#  ('2431V', 'PMM2', 'HA', 'Het', 'ENST00000382298.3:c.12218T>C\n'),
#  ('2431V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12213A>C\n'),
#  ('2431V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12212A>T\n'),
#  ('2431V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12211G>T\n'),
#  ('2431V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12206G>A\n'),
#  ('400Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12218T>C\n'),
#  ('400Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12213A>C\n'),
#  ('400Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12212A>T\n'),
#  ('400Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12211G>T\n'),
#  ('400Z', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12206G>A\n'),
#  ('642X', 'RARS2', 'HA', 'Het', 'ENST00000382298.3:c.12212A>T\n'),
#  ('642X', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12211G>T\n'),
#  ('642X', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.12206G>A\n'),
#  ('642X', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5473G>T\n'),
#  ('642X', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5471T>A\n'),
#  ('470V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5473G>T\n'),
#  ('470V', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5471T>A\n'),
#  ('745A', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5473G>T\n'),
#  ('745A', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.5471T>A\n'),
#  ('2576B ', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.13717A>C\n'),
#  ('2576B ', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.10982C>T\n'),
#  ('2477B', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.4430T>C\n'),
#  ('2477B', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.2225G>C\n'),
#  ('1055B', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.7231A>G\n'),
#  ('1055B', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.2185+56T>A\n'),
#  ('2274t', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.1702G>A\n'),
#  ('2274t', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.20+32T>A\n'),
#  ('795C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.4757A>G\n'),
#  ('795C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.11048A>G\n'),
#  ('795C',
#   'unsure',
#   'CMT',
#   'Hom',
#   'ENST00000382298.3:c.21-16541_21-16540delCA\n'),
#  ('795C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.21-16822A>G\n'),
#  ('795C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.21-16844C>T\n'),
#  ('795C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.-501-2320C>A\n'),
#  ('795C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.-501-6902G>T\n'),
#  ('795C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.-502+7246T>C\n'),
#  ('795C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.-502+7148G>C\n'),
#  ('795C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.-502+7087A>G\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.259+434G>A\n'),
#  ('694C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.8022T>C\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.457+1637C>T\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.457+774C>T\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.260-392A>C\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.260-402A>G\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.171+1057C>T\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.21-16429G>A\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.20+16642C>T\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.20+8256_20+8257insA\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.20+8232C>T\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.-501-2491T>G\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.-501-2797dupA\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.-502+7246T>C\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.-502+7148G>C\n'),
#  ('362C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.10611A>G\n'),
#  ('362C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.1656A>G\n'),
#  ('362C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.696T>A\n'),
#  ('362C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.605-99C>T\n'),
#  ('362C',
#   'unsure',
#   'CMT',
#   'Hom',
#   'ENST00000382298.3:c.21-16304_21-16303delGC\n'),
#  ('362C',
#   'unsure',
#   'CMT',
#   'Hom',
#   'ENST00000382298.3:c.21-16541_21-16540delCA\n'),
#  ('362C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.20+15165T>C\n'),
#  ('362C',
#   'unsure',
#   'CMT',
#   'Hom',
#   'ENST00000382298.3:c.20+13816_20+13820delGAGAT\n'),
#  ('362C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.20+11786C>T\n'),
#  ('744C', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.11032C>G\n'),
#  ('744C', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.1656A>G\n'),
#  ('744C', 'unsure', 'HA', 'Het', 'ENST00000382298.3:c.696T>A\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.457+1637C>T\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.260-392A>C\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.260-402A>G\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.260-433A>G\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.21-10591C>T\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.21-10606C>A\n'),
#  ('744C',
#   'unsure',
#   'HA',
#   'Hom',
#   'ENST00000382298.3:c.21-16304_21-16303delGC\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.-501-1373C>A\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.9981T>C\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.171+6C>T\n'),
#  ('873C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.10338G>A\n'),
#  ('959C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.11032C>G\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.2185+3226T>A\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.2185+3225A>C\n'),
#  ('959C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.1656A>G\n'),
#  ('959C', 'unsure', 'CMT', 'Het', 'ENST00000382298.3:c.696T>A\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.21-10591C>T\n'),
#  ('959C',
#   'unsure',
#   'CMT',
#   'Hom',
#   'ENST00000382298.3:c.21-16304_21-16303delGC\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.20+17180T>C\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.20+17128C>T\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.20+5837A>C\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.20+5833T>C\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.20+3385C>T\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.-502+6895C>T\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000382298.3:c.-502+6885G>A\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.9981T>C\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.909A>G\n'),
#  ('971C', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.10338G>A\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.*484T>C\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.2186-1870G>T\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.2185+2084A>G\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.21-10606C>A\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.21-16166A>G\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.21-16171T>C\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.20+15165T>C\n'),
#  ('1251C',
#   'unsure',
#   'HA',
#   'Hom',
#   'ENST00000382298.3:c.-502+6974_-502+6975delTT\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.-502+6895C>T\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.-502+6885G>A\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.-502+5950A>G\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000382298.3:c.-502+5810C>G\n'),
#  ('1594B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.10042T>C\n'),
#  ('1594B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.346-47G>A\n'),
#  ('1594B', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.10338G>A\n'),
#  ('1594B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.696T>A\n'),
#  ('1594B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.909A>G\n'),
#  ('1594B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.605-99C>T\n'),
#  ('1594B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.1656A>G\n'),
#  ('2625B', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.2186-1768C>T\n'),
#  ('2625B', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.457+774C>T\n'),
#  ('2625B', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.21-10194C>T\n'),
#  ('2625B', 'unsure', 'HSP', 'Hom', 'ENST00000382298.3:c.21-17670G>A\n'),
#  ('2625B',
#   'unsure',
#   'HSP',
#   'Het',
#   'ENST00000382298.3:c.20+8256_20+8257insA\n'),
#  ('2625B', 'unsure', 'HSP', 'Het', 'ENST00000382298.3:c.20+8232C>T\n')]

# %%
# sacs 
V_sacs_hgvs = VCF("SACS/P4_pisa/P4_pisa_sacs_vep_v2.vcf")


lines_f = []
for v in V_sacs_hgvs:
    hgvs_c = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000382298.3"][0]
    hgvs_p = [tr.split("|")[11] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000382298.3"][0]
    chrom = v.CHROM
    pos = v.POS
    ref = v.REF
    alt = v.ALT[0]
    
    
    for entry in pisa_sacs_hgvs:
        if entry[4].strip()==hgvs_c:
            sub = "P4 - Pisa"
            local_id = entry[0]
            f_id = "F_" + local_id
            prospax = ""
            ngs_db = "Pisa Diagnostic Pipeline"
            main_phe = entry[2]
            case_solved = entry[1]
            v_id = ""
            tr = "ENST00000382298.3"
            hgvs_c_f = hgvs_c.split(":")[1]
            genotype = entry[3]
            
            cmpd = ""
            pax = ""
            pbmc = ""
            fibr = ""
            comment = ""
            
            lines_f.append([sub, local_id, f_id, prospax, ngs_db, main_phe, case_solved,
                          v_id, "SACS", chrom, pos, ref, alt, tr, hgvs_c_f, hgvs_p, genotype, cmpd,
                          pbmc, pax, fibr, comment])

# %%
def create_row_manual(sub, local_id, f_id, ngs_db, main_phe, case_solved,
                           gene, chrom, pos, ref, alt, tr, hgvsc, hgvsp, genotype, v_id="", prospax="",cmpd="",
                          pbmc="", pax="", fibr="", comment=""):
    return [sub, local_id, f_id, prospax, ngs_db, main_phe, case_solved,
                          v_id, gene, chrom, pos, ref, alt, tr, hgvsc, hgvsp, genotype, cmpd,
                          pbmc, pax, fibr, comment]

# %%
# manual variant
missing = [h for h in pisa_sacs_hgvs if h[4].split(":")[1].strip() not in list(df_p4_sacs['cDNA change (e.g. '].unique())]
for l in missing:
    n_row = create_row_manual("P4 - Pisa", l[0], "F_"+l[0], "Pisa Diagnostic Pipeline", l[2],
                             l[1], "SACS", "13", "", "", "", "ENST00000382298.3", l[4],
                             "", l[3])
    lines_f.append(n_row)

# %%
df_p4_sacs = pd.DataFrame(lines_f, columns=list(df_sacs.columns)[:-1])

# %%
df_p4_sacs.drop_duplicates(inplace=True)

# %%
df_p4_sacs.shape
# Out:
# (197, 22)

# %%
df_p4_sacs.to_csv("SACS/P4_pisa/P4_SACS_variant_collection.v1.tsv", sep="\t", index=False)

# %%
[h for h in pisa_sacs_hgvs_c if h.split(":")[1].strip() not in list(df_p4_sacs['cDNA change (e.g. '].unique())]
# Out:
# ['ENST00000382298.3:c.259+74_259+76delTTT\n',
#  'ENST00000382298.3:c.2186-632delA\n',
#  'ENST00000382298.3:c.21-16304_21-16303delGC\n',
#  'ENST00000382298.3:c.2186-622_2186-621insA\n',
#  'ENST00000382298.3:c.2094-63delG\n',
#  'ENST00000382298.3:c.2216A>G/c.4466A>G\n',
#  'ENST00000382298.3:c.-501-2797dupA\n',
#  'ENST00000382298.3:c.5151dupA\n',
#  'ENST00000382298.3:c.6393T>C ?\n',
#  'ENST00000382298.3:c.-502+6974_-502+6975delTT\n',
#  'ENST00000382298.3:c.6557_6559delGTA\n',
#  'ENST00000382298.3:c.21-16541_21-16540delCA\n',
#  'ENST00000382298.3:c.20+13816_20+13820delGAGAT\n',
#  'ENST00000382298.3:c.11353_11354delAG\n']

# %%
# spg7
V_spg7_hgvs = VCF("SPG7/P4_pisa/P4_pisa_spg7_vep_v2.vcf")

lines_f_spg7 = []
for v in V_spg7_hgvs:
    hgvs_c = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000268704.2"][0]
    hgvs_p = [tr.split("|")[11] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000268704.2"][0]
    
    chrom = v.CHROM
    pos = v.POS
    ref = v.REF
    alt = v.ALT[0]
    
    for entry in pisa_spg7_hgvs:
        if entry[4].strip()==hgvs_c:
            sub = "P4 - Pisa"
            local_id = entry[0]
            f_id = "F_" + local_id
            prospax = ""
            ngs_db = "Pisa Diagnostic Pipeline"
            main_phe = entry[2]
            case_solved = entry[1]
            v_id = ""
            tr = "ENST00000268704.2"
            hgvs_c_f = hgvs_c.split(":")[1]
            genotype = entry[3]
            
            cmpd = ""
            pax = ""
            pbmc = ""
            fibr = ""
            comment = ""
            
            lines_f_spg7.append([sub, local_id, f_id, prospax, ngs_db, main_phe, case_solved,
                          v_id, "SPG7", chrom, pos, ref, alt, tr, hgvs_c_f, hgvs_p, genotype, cmpd,
                          pbmc, pax, fibr, comment])

# %%
df_p4_spg7 = pd.DataFrame(lines_f_spg7, columns=list(df_sacs.columns)[:-1])
df_p4_spg7.drop_duplicates(inplace=True)
df_p4_spg7.shape
# Out:
# (238, 22)

# %%
len([h for h in pisa_spg7_hgvs if h[4].split(":")[1].strip() not in list(df_p4_spg7['cDNA change (e.g. '].unique())])
# Out:
# 55

# %%
# manual variant
missing = [h for h in pisa_spg7_hgvs if h[4].split(":")[1].strip() not in list(df_p4_spg7['cDNA change (e.g. '].unique())]
for l in missing:
    n_row = create_row_manual("P4 - Pisa", l[0], "F_"+l[0], "Pisa Diagnostic Pipeline", l[2],
                             l[1], "SPG7", "16", "", "", "", "ENST00000268704.2", l[4],
                             "", l[3])
    lines_f_spg7.append(n_row)

# %%
df_p4_spg7 = pd.DataFrame(lines_f_spg7, columns=list(df_spg7.columns))
df_p4_spg7.drop_duplicates(inplace=True)
df_p4_spg7.shape
# Out:
# (293, 22)

# %%
df_p4_spg7.to_csv("SPG7/P4_pisa/P4_SPG7_variant_collection.v1.tsv", sep="\t", index=False)

# %%
V_spg7_hgvs = VCF("SPG7/P4_pisa/P4_pisa_spg7_vep_v2.vcf")
ids = [v.ID for v in V_spg7_hgvs]
miss = [h for h in pisa_spg7_hgvs if h[4].strip() not in ids]

# %%
miss
# Out:
# [('245B', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.-1G>A\n'),
#  ('052A', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1325-60A>G\n'),
#  ('1496A', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.*38G>T\n'),
#  ('2110T', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1325-20C>T\n'),
#  ('896X', 'unsure', 'HA', 'Het', 'ENST00000268704.2:c.51+751C>G\n'),
#  ('2781X', 'KCNA2', 'HA', 'Het', 'ENST00000268704.2:c.51+751C>G\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.51+537G>C\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.51+18C>G\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.992A>G\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.51+18C>G\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.992A>G\n'),
#  ('1594B', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.992A>G\n'),
#  ('1594B', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.51+18C>G\n')]

# %%
missing
# Out:
# [('701C', 'SPG7', 'HSP', 'Het', 'ENST00000268704.2:c.773_774delTG\n'),
#  ('2418A',
#   'unsure',
#   'HSP',
#   'Hom?',
#   'ENST00000268704.2:c.2181+155_2181+161delGTGTTCC\n'),
#  ('245B', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.-1G>A\n'),
#  ('2711A',
#   'unsure',
#   'HSP',
#   'Hom?',
#   'ENST00000268704.2:c.184-19_184-18delGT\n'),
#  ('052A', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1325-60A>G\n'),
#  ('1496A', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.*38G>T\n'),
#  ('1443X',
#   'unsure',
#   'HSP',
#   'Hom?',
#   'ENST00000268704.2:c.1780-17_1780-15delTCT\n'),
#  ('2110T', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1325-20C>T\n'),
#  ('1825X',
#   'unsure',
#   'HSP',
#   'Hom?',
#   'ENST00000268704.2:c.1324+136_1324+137insA\n'),
#  ('896X', 'unsure', 'HA', 'Het', 'ENST00000268704.2:c.51+751C>G\n'),
#  ('2781X', 'KCNA2', 'HA', 'Het', 'ENST00000268704.2:c.51+751C>G\n'),
#  ('2446V', 'SPG7', 'HA', 'Hom', 'ENST00000268704.2:c.73_80delCCAGGCCC\n'),
#  ('194Z',
#   'unsure',
#   'HA',
#   'Hom',
#   'ENST00000268704.2:c.1780-17_1780-15delTCT\n'),
#  ('180Z',
#   'unsure',
#   'HA',
#   'Hom',
#   'ENST00000268704.2:c.1325-160_1325-156delAGGTG\n'),
#  ('179Z',
#   'RNF216',
#   'HA',
#   'Hom',
#   'ENST00000268704.2:c.988-131_988-114delTTTGAGGCTGCAGTGAGC\n'),
#  ('1175a ',
#   'unsure',
#   'HA',
#   'Hom',
#   'ENST00000268704.2:c.1780-16_1780-14delCTT\n'),
#  ('729A', 'unsure', 'HA', 'Hom', 'ENST00000268704.2:c.988-74delA\n'),
#  ('716A',
#   'unsure',
#   'HA',
#   'Hom',
#   'ENST00000268704.2:c.2181+155_2181+161delGTGTTCC\n'),
#  ('2272R', 'unsure', 'HA', 'Hom', 'ENST00000268704.2:c.184-19_184-17delGTT\n'),
#  ('1175a',
#   'unsure',
#   'HA',
#   'Hom',
#   'ENST00000268704.2:c.1780-16_1780-14delCTT\n'),
#  ('795C', 'unsure', 'CMT', 'Het', 'ENST00000268704.2:c.184-4delT\n'),
#  ('795C', 'unsure', 'CMT', 'Hom', 'ENST00000268704.2:c.377-4410delT\n'),
#  ('795C', 'unsure', 'CMT', 'Het', 'ENST00000268704.2:c.1450-75delC\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.51+537G>C\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.184-4delT\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.376+726delT\n'),
#  ('694C', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.1324+148dupA\n'),
#  ('362C', 'unsure', 'CMT', 'Het', 'ENST00000268704.2:c.377-3286delT\n'),
#  ('362C', 'unsure', 'CMT', 'Het', 'ENST00000268704.2:c.1450-75delC\n'),
#  ('744C', 'unsure', 'HA', 'Het', 'ENST00000268704.2:c.184-4delT\n'),
#  ('744C', 'unsure', 'HA', 'Hom', 'ENST00000268704.2:c.376+4184dupG\n'),
#  ('744C', 'unsure', 'HA', 'Het', 'ENST00000268704.2:c.1324+148dupA\n'),
#  ('744C', 'unsure', 'HA', 'Het', 'ENST00000268704.2:c.1450-801dupT\n'),
#  ('744C', 'unsure', 'HA', 'Het', 'ENST00000268704.2:c.1450-75delC\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.51+18C>G\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.184-4delT\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.992A>G\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1450-75delC\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1324+148dupA\n'),
#  ('873C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1450-801dupT\n'),
#  ('959C', 'unsure', 'CMT', 'Hom', 'ENST00000268704.2:c.1450-75delC\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.51+18C>G\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.184-4delT\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1324+148dupA\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1450-75delC\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.992A>G\n'),
#  ('971C', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1450-801dupT\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000268704.2:c.184-4delT\n'),
#  ('1251C', 'unsure', 'HA', 'Hom', 'ENST00000268704.2:c.1324+148dupA\n'),
#  ('1594B', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.992A>G\n'),
#  ('1594B', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.184-4delT\n'),
#  ('1594B', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.1324+148dupA\n'),
#  ('1594B', 'unsure', 'HSP', 'Hom', 'ENST00000268704.2:c.51+18C>G\n'),
#  ('2625B', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1324+148dupA\n'),
#  ('2625B', 'unsure', 'HSP', 'Het', 'ENST00000268704.2:c.1450-75delC\n')]

# %% [markdown]
# # Nijmegen

# %%
df_sacs_nij = pd.read_csv("SACS/P3_nijmegen/SACS varianten MPEN BvdW 25-11.xlsx - Blad1.tsv", sep="\t")
df_spg7_nij = pd.read_csv("SPG7/P3_nijmegen/SPG7 varianten MPEN BvdW 25-11.xlsx - Blad1.tsv", sep="\t")

df_sacs_nij['Number of patients with this variant'] = df_sacs_nij['Number of patients with this variant'].fillna(' ')
df_spg7_nij['Number of patients with this variant'] = df_spg7_nij['Number of patients with this variant'].fillna(' ')

# %%
df_sacs_nij.columns
# Out:
# Index(['Variant (genomic)', 'Variant ((non)coding)', 'Variant (rna/protein)',
#        'Classification', 'Phenotype', 'Number of patients with this variant',
#        'Other variant in this gene (if applicable)'],
#       dtype='object')

# %%
df_spg7_nij.columns
# Out:
# Index(['Variant (genomic)', 'Variant ((non)coding)', 'Variant (rna/protein)',
#        'Classification', 'Phenotype', 'Number of patients with this variant',
#        'Other variant in this gene (if applicable)'],
#       dtype='object')

# %%
nij_raw_rows_sacs = []
for idx, row in df_sacs_nij.iterrows():
    hgvsg = row['Variant (genomic)']
    main_phenotype = row['Phenotype']
    comment = "nb="+row['Number of patients with this variant']+";"+"comments="+row['Other variant in this gene (if applicable)']
    
    nij_raw_rows_sacs.append([hgvsg, main_phenotype, comment])

# %%
nij_raw_rows_spg7 = []
for idx, row in df_spg7_nij.iterrows():
    hgvsg = row['Variant (genomic)']
    main_phenotype = row['Phenotype']
    comment = "nb="+row['Number of patients with this variant']+";"+"comments="+row['Other variant in this gene (if applicable)']
    
    nij_raw_rows_spg7.append([hgvsg, main_phenotype, comment])

# %%
with open("SACS/P3_nijmegen/SACS_2_vep.txt", "w") as f:
    for e in nij_raw_rows_sacs:
        f.write(e[0] + "\n")
        
with open("SPG7/P3_nijmegen/SPG7_2_vep.txt", "w") as f:
    for e in nij_raw_rows_spg7:
        f.write(e[0] + "\n")

# %%
V_nij_sacs = VCF("SACS/P3_nijmegen/P3_SACS_fromVep.vcf.vcf")


nij_lines_f_sacs = []
for v in V_nij_sacs:
    hgvs_c = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000382298.3"][0]
    hgvs_p = [tr.split("|")[11] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000382298.3"][0]
    
    chrom = v.CHROM
    pos = v.POS
    ref = v.REF
    alt = v.ALT[0]
    
    idx = v.ID
    
    for entry in nij_raw_rows_sacs:
        if entry[0]==idx:
            sub = "P3 - Nijgemen"
            local_id = entry[0]
            f_id = "F_" + local_id
            prospax = ""
            ngs_db = "Nijgemen Diagnostic Pipeline"
            main_phe = entry[1]
            case_solved = ""
            v_id = ""
            tr = "ENST00000382298.3"
            hgvs_c_f = hgvs_c.split(":")[1]
            genotype = ""
            
            cmpd = ""
            pax = ""
            pbmc = ""
            fibr = ""
            comment = entry[2]
            
            nij_lines_f_sacs.append([sub, local_id, f_id, prospax, ngs_db, main_phe, case_solved,
                          v_id, "SACS", chrom, pos, ref, alt, tr, hgvs_c_f, hgvs_p, genotype, cmpd,
                          pbmc, pax, fibr, comment])

# %%
nij_sacs_df = pd.DataFrame(nij_lines_f_sacs, columns=df_p4_sacs.columns)

nij_sacs_df.to_csv("SACS/P3_nijmegen/P3_Nijmegen_variant_collection.v1.tsv", sep="\t", index=False)

# %%
V_nij_spg7 = VCF("SPG7/P3_nijmegen/P3_SPG7_fromVep.vcf.vcf")


nij_lines_f_spg7 = []
for v in V_nij_spg7:
    hgvs_c = [tr.split("|")[10] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000268704.2"][0]
    hgvs_p = [tr.split("|")[11] for tr in v.INFO["CSQ"].split(",") if tr.split("|")[6] =="ENST00000268704.2"][0]
    
    chrom = v.CHROM
    pos = v.POS
    ref = v.REF
    alt = v.ALT[0]
    
    idx = v.ID
    
    for entry in nij_raw_rows_spg7:
        if entry[0]==idx:
            sub = "P3 - Nijgemen"
            local_id = entry[0]
            f_id = "F_" + local_id
            prospax = ""
            ngs_db = "Nijgemen Diagnostic Pipeline"
            main_phe = entry[1]
            case_solved = ""
            v_id = ""
            tr = "ENST00000268704.2"
            hgvs_c_f = hgvs_c.split(":")[1]
            genotype = ""
            
            cmpd = ""
            pax = ""
            pbmc = ""
            fibr = ""
            comment = entry[2]
            
            nij_lines_f_spg7.append([sub, local_id, f_id, prospax, ngs_db, main_phe, case_solved,
                          v_id, "SPG7", chrom, pos, ref, alt, tr, hgvs_c_f, hgvs_p, genotype, cmpd,
                          pbmc, pax, fibr, comment])

# %%
len(nij_raw_rows_spg7)
# Out:
# 34

# %%
len(nij_lines_f_spg7)
# Out:
# 34

# %%
nij_spg7_df = pd.DataFrame(nij_lines_f_spg7, columns=df_p4_spg7.columns)

nij_spg7_df.to_csv("SPG7/P3_nijmegen/P3_Nijmegen_variant_collection.v1.tsv", sep="\t", index=False)

# %%
df_spg7_nij
# Out:
#                          Variant (genomic) Variant ((non)coding)  \
# 0              Chr16(GRCh37):g.89574828G>A                c.3G>A
# 1              Chr16(GRCh37):g.89574859C>T               c.34C>T
# 2              Chr16(GRCh37):g.89574971C>T              c.146C>T
# 3   Chr16(GRCh37):g.89579404_89579405insTA        c.335_336insTA
# 4              Chr16(GRCh37):g.89590648G>T              c.611G>T
# 5              Chr16(GRCh37):g.89592812del              c.694del
# 6              Chr16(GRCh37):g.89595987dup              c.861dup
# 7              Chr16(GRCh37):g.89595989dup            c.861+2dup
# 8     Chr16(GRCh37):g.89598270_89598370del      c.988-42_1046del
# 9              Chr16(GRCh37):g.89598369G>A             c.1045G>A
# 10             Chr16(GRCh37):g.89598372C>A             c.1048C>A
# 11             Chr16(GRCh37):g.89598372C>T             c.1048C>T
# 12             Chr16(GRCh37):g.89598377dup             c.1053dup
# 13             Chr16(GRCh37):g.89598912C>T             c.1192C>T
# 14             Chr16(GRCh37):g.89599025G>T             c.1305G>T
# 15             Chr16(GRCh37):g.89599044G>C             c.1324G>C
# 16             Chr16(GRCh37):g.89613069A>G             c.1453A>G
# 17    Chr16(GRCh37):g.89613070_89613078del        c.1454_1462del
# 18             Chr16(GRCh37):g.89613145C>T             c.1529C>T
# 19             Chr16(GRCh37):g.89613159G>C             c.1543G>C
# 20    Chr16(GRCh37):g.89614409_89614410del    c.1553-2_1553-1del
# 21             Chr16(GRCh37):g.89614459G>A             c.1601G>A
# 22             Chr16(GRCh37):g.89616940C>T             c.1702C>T
# 23             Chr16(GRCh37):g.89616987G>C             c.1749G>C
# 24             Chr16(GRCh37):g.89616994G>T             c.1756G>T
# 25             Chr16(GRCh37):g.89619403G>T             c.1796G>T
# 26             Chr16(GRCh37):g.89619501G>A             c.1894G>A
# 27             Chr16(GRCh37):g.89620213G>T             c.1948G>T
# 28             Chr16(GRCh37):g.89620348C>G             c.2083C>G
# 29             Chr16(GRCh37):g.89620355A>C             c.2090A>C
# 30             Chr16(GRCh37):g.89620367A>C             c.2102A>C
# 31    Chr16(GRCh37):g.89620905_89620921del        c.2115_2131del
# 32             Chr16(GRCh37):g.89623341T>C             c.2228T>C
# 33             Chr16(GRCh37):g.89623353T>C             c.2240T>C
#
#    Variant (rna/protein) Classification  \
# 0              p.(Met1?)        class 5
# 1           p.(Arg12Cys)        class 3
# 2           p.(Pro49Leu)        class 3
# 3           p.(Glu112fs)        class 5
# 4          p.(Gly204Val)        class 3
# 5           p.(Glu232fs)        class 5
# 6           p.((Asn288*)        class 5
# 7               r.(spl?)        class 5
# 8               r.(spl?)        class 5
# 9          p.(Gly349Ser)        class 4
# 10         p.(Pro350Thr)        class 3
# 11         p.(Pro350Ser)        class 3
# 12          p.(Gly352fs)        class 5
# 13           p.(Arg398*)        class 5
# 14         p.(Gln435His)        class 3
# 15         p.(Gly442Arg)        class 3
# 16         p.(Arg485Gly)        class 3
# 17  p.(Arg485_Glu487del)        class 5
# 18         p.(Ala510Val)        class 5
# 19         p.(Gly515Arg)        class 3
# 20              r.(spl?)        class 5
# 21         p.(Arg534Gln)        class 3
# 22           p.(Gln568*)        class 5
# 23         p.(Trp583Cys)        class 4
# 24           p.(Glu586*)        class 5
# 25         p.(Arg599Leu)        class 3
# 26         p.(Gly632Arg)        class 3
# 27         p.(Asp650Tyr)        class 3
# 28         p.(Leu695Val)        class 3
# 29         p.(Gln697Pro)        class 3
# 30         p.(His701Pro)        class 4
# 31          p.(Leu706fs)        class 5
# 32         p.(Ile743Thr)        class 3
# 33         p.(Ile747Thr)        class 3
#
#                                             Phenotype  \
# 0                                  Spastic paraplegia
# 1                                  Spastic paraplegia
# 2                                  Spastic paraplegia
# 3                              spinocerebellar ataxia
# 4                                 spastic paraplegia
# 5        spastic ataxia, cerebral visual disturbances
# 6   Spastic paraplegia / progressive bipyramidal s...
# 7                                  Spastic paraplegia
# 8                                  Spastic paraplegia
# 9                                  Spastic paraplegia
# 10                                 Spastic paraplegia
# 11                                 Spastic paraplegia
# 12             Spastic paraplegia / cerebellar Ataxia
# 13                                 Spastic paraplegia
# 14                                 Spastic paraplegia
# 15                             spinocerebellar ataxia
# 16                                 Spastic paraplegia
# 17                                 Spastic paraplegia
# 18                                 Spastic paraplegia
# 19                                 Spastic paraplegia
# 20                                             Ataxia
# 21                                 Spastic paraplegia
# 22                                 Spastic paraplegia
# 23                                 Spastic paraplegia
# 24                                             Ataxia
# 25                                 Spastic paraplegia
# 26                                 Spastic paraplegia
# 27                                 Spastic paraplegia
# 28                                 Spastic paraplegia
# 29                                 Spastic paraplegia
# 30                                 Spastic paraplegia
# 31                                 Spastic paraplegia
# 32                                 Spastic paraplegia
# 33                                 Spastic paraplegia
#
#    Number of patients with this variant  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5
# 6                                    4x
# 7                                    3x
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                   2x
# 13                                  NaN
# 14                                   3x
# 15                                  NaN
# 16                                  NaN
# 17                                  >20
# 18                                  >20
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                   2x
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# 30                                   3x
# 31                                   4x
# 32                                  NaN
# 33                                  NaN
#
#            Other variant in this gene (if applicable)
# 0                                          homozygous
# 1                                              no 2nd
# 2                       no 2nd (not highly conserved)
# 3                          comp het. (with c.1324G>C)
# 4                                              no 2nd
# 5                          comp het. (with c.1529C>T)
# 6   no 2nd / comp het. (c.1045G>A) / comp het. del...
# 7                 2x comp het. (c.1045G>A) / No 2nd
# 8                          comp het. (c.1454_1462del)
# 9                              found many times (>20)
# 10                                             no 2nd
# 11                                             no 2nd
# 12     comp het. (c.1749G>C) /  comp het. (c.2228T>C)
# 13                              comp het. (c.1529C>T)
# 14  comp het. (c.2275G>A)/ comp het. (c.Ala749Thr)...
# 15                          comp het (c.335_336insTA)
# 16                                         homozygous
# 17                             found many times (>20)
# 18                             found many times (>20)
# 19                                             no 2nd
# 20                                             no 2nd
# 21                                             no 2nd
# 22                              comp het. (c.1045G>A)
# 23                              comp het. (c.1053dup)
# 24                              comp het. (c.1529C>T)
# 25                                             no 2nd
# 26                         both comp het. (c.1529C>T)
# 27                                         homozygous
# 28                                             no 2nd
# 29                              comp het. (c.1045G>A)
# 30   homozygous / comp het. (c.1454_1462del) / no 2nd
# 31  comp het. (1045G>A) / comp het. (c.1454_1462de...
# 32                               comp het. (c.861dup)
# 33                         comp het. (c.1454_1462del)

# %% [markdown]
# ---------------

# %%
import requests, sys, json
from pprint import pprint

def fetch_endpoint(server, request, content_type):

    r = requests.get(server+request, headers={ "Accept" : content_type})

    if not r.ok:
        r.raise_for_status()
        sys.exit()

    if content_type == 'application/json':
        return r.json()
    else:
        return r.text

def fetch_endpoint_POST(server, request, data, content_type):

    r = requests.post(server+request,
                      headers={ "Accept" : content_type},
                      data=data )

    if not r.ok:
        r.raise_for_status()
        sys.exit()

    if content_type == 'application/json':
        return r.json()
    else:
        return r.text

# define the server, extension and content type
server = "http://rest.ensembl.org/"
con = "application/json"
vep_ext = "vep/homo_sapiens/hgvs/vcf=-"

# create the list of HGVS annotations
hgvs = ["SACS:c.2094-63delG","SACS:c.11353_11354delAG","SACS:c.6557_6559delGTA",
        "SACS:c.2186-622_2186-621insA","SACS:c.2186-632delA","SACS:c.259+74_259+76delTTT",
        "SACS:c.5151dupA","SACS:c.2216A>G/c.4466A>G","SACS:c.6393T>C","SACS:c.21-16541_21-16540delCA",
        "SACS:c.-501-2797dupA","SACS:c.21-16304_21-16303delGC","SACS:c.21-16541_21-16540delCA",
        "SACS:c.20+13816_20+13820delGAGAT","SACS:c.21-16304_21-16303delGC","SACS:c.21-16304_21-16303delGC",
        "SACS:c.-502+6974_-502+6975delTT"
]

# convert the list into json format
hgvs_json = json.dumps({ "hgvs_notations" : hgvs })

# run the query
post_vep = fetch_endpoint_POST(server, vep_ext, hgvs_json, con)

# %%
post_vep[0]
# Out:
# {'id': 'SACS:c.2094-63delG',
#  'end': 23353939,
#  'input': 'SACS:c.2094-63delG',
#  'most_severe_consequence': 'intron_variant',
#  'transcript_consequences': [{'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'variant_allele': '-',
#    'strand': -1,
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000382292',
#    'consequence_terms': ['intron_variant'],
#    'impact': 'MODIFIER',
#    'biotype': 'protein_coding',
#    'hgnc_id': 'HGNC:10519'},
#   {'strand': -1,
#    'variant_allele': '-',
#    'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'hgnc_id': 'HGNC:10519',
#    'gene_symbol_source': 'HGNC',
#    'consequence_terms': ['intron_variant'],
#    'transcript_id': 'ENST00000402364',
#    'impact': 'MODIFIER',
#    'biotype': 'protein_coding'},
#   {'hgnc_id': 'HGNC:10519',
#    'biotype': 'protein_coding',
#    'consequence_terms': ['intron_variant'],
#    'transcript_id': 'ENST00000423156',
#    'gene_symbol_source': 'HGNC',
#    'impact': 'MODIFIER',
#    'strand': -1,
#    'variant_allele': '-',
#    'gene_id': 'ENSG00000151835',
#    'gene_symbol': 'SACS'},
#   {'gene_id': 'ENSG00000151835',
#    'gene_symbol': 'SACS',
#    'variant_allele': '-',
#    'strand': -1,
#    'biotype': 'protein_coding',
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000455470',
#    'consequence_terms': ['intron_variant'],
#    'impact': 'MODIFIER',
#    'hgnc_id': 'HGNC:10519'},
#   {'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'variant_allele': '-',
#    'strand': -1,
#    'consequence_terms': ['intron_variant', 'non_coding_transcript_variant'],
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000476776',
#    'impact': 'MODIFIER',
#    'biotype': 'processed_transcript',
#    'hgnc_id': 'HGNC:10519'},
#   {'hgnc_id': 'HGNC:10519',
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000682775',
#    'impact': 'MODIFIER',
#    'consequence_terms': ['intron_variant'],
#    'biotype': 'protein_coding',
#    'variant_allele': '-',
#    'strand': -1,
#    'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835'},
#   {'hgnc_id': 'HGNC:10519',
#    'biotype': 'protein_coding',
#    'gene_symbol_source': 'HGNC',
#    'consequence_terms': ['intron_variant'],
#    'transcript_id': 'ENST00000682944',
#    'impact': 'MODIFIER',
#    'strand': -1,
#    'variant_allele': '-',
#    'gene_id': 'ENSG00000151835',
#    'gene_symbol': 'SACS'},
#   {'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'strand': -1,
#    'variant_allele': '-',
#    'distance': 29,
#    'gene_symbol_source': 'HGNC',
#    'consequence_terms': ['downstream_gene_variant'],
#    'transcript_id': 'ENST00000683154',
#    'impact': 'MODIFIER',
#    'biotype': 'retained_intron',
#    'hgnc_id': 'HGNC:10519'},
#   {'consequence_terms': ['intron_variant'],
#    'gene_symbol_source': 'HGNC',
#    'impact': 'MODIFIER',
#    'transcript_id': 'ENST00000683210',
#    'biotype': 'protein_coding',
#    'hgnc_id': 'HGNC:10519',
#    'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'variant_allele': '-',
#    'strand': -1},
#   {'strand': -1,
#    'variant_allele': '-',
#    'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'hgnc_id': 'HGNC:10519',
#    'gene_symbol_source': 'HGNC',
#    'consequence_terms': ['intron_variant'],
#    'transcript_id': 'ENST00000683270',
#    'impact': 'MODIFIER',
#    'biotype': 'protein_coding'},
#   {'gene_id': 'ENSG00000151835',
#    'gene_symbol': 'SACS',
#    'strand': -1,
#    'variant_allele': '-',
#    'biotype': 'protein_coding',
#    'consequence_terms': ['intron_variant'],
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000683367',
#    'impact': 'MODIFIER',
#    'hgnc_id': 'HGNC:10519'},
#   {'gene_id': 'ENSG00000151835',
#    'gene_symbol': 'SACS',
#    'strand': -1,
#    'variant_allele': '-',
#    'biotype': 'protein_coding',
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000683489',
#    'consequence_terms': ['intron_variant'],
#    'impact': 'MODIFIER',
#    'hgnc_id': 'HGNC:10519'},
#   {'variant_allele': '-',
#    'strand': -1,
#    'gene_id': 'ENSG00000151835',
#    'gene_symbol': 'SACS',
#    'hgnc_id': 'HGNC:10519',
#    'biotype': 'protein_coding',
#    'consequence_terms': ['intron_variant'],
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000683680',
#    'impact': 'MODIFIER'},
#   {'hgnc_id': 'HGNC:10519',
#    'transcript_id': 'ENST00000684163',
#    'consequence_terms': ['intron_variant'],
#    'gene_symbol_source': 'HGNC',
#    'impact': 'MODIFIER',
#    'biotype': 'protein_coding',
#    'variant_allele': '-',
#    'strand': -1,
#    'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835'},
#   {'gene_id': 'ENSG00000151835',
#    'gene_symbol': 'SACS',
#    'variant_allele': '-',
#    'strand': -1,
#    'biotype': 'retained_intron',
#    'gene_symbol_source': 'HGNC',
#    'consequence_terms': ['intron_variant', 'non_coding_transcript_variant'],
#    'transcript_id': 'ENST00000684196',
#    'impact': 'MODIFIER',
#    'hgnc_id': 'HGNC:10519'},
#   {'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'variant_allele': '-',
#    'strand': -1,
#    'transcript_id': 'ENST00000684325',
#    'gene_symbol_source': 'HGNC',
#    'consequence_terms': ['intron_variant', 'NMD_transcript_variant'],
#    'impact': 'MODIFIER',
#    'biotype': 'nonsense_mediated_decay',
#    'hgnc_id': 'HGNC:10519'},
#   {'strand': -1,
#    'variant_allele': '-',
#    'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'hgnc_id': 'HGNC:10519',
#    'consequence_terms': ['intron_variant'],
#    'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000684385',
#    'impact': 'MODIFIER',
#    'biotype': 'protein_coding'},
#   {'gene_symbol_source': 'HGNC',
#    'transcript_id': 'ENST00000684497',
#    'impact': 'MODIFIER',
#    'consequence_terms': ['intron_variant'],
#    'biotype': 'protein_coding',
#    'hgnc_id': 'HGNC:10519',
#    'gene_symbol': 'SACS',
#    'gene_id': 'ENSG00000151835',
#    'variant_allele': '-',
#    'strand': -1}],
#  'assembly_name': 'GRCh38',
#  'seq_region_name': '13',
#  'allele_string': 'G/-',
#  'strand': -1,
#  'start': 23353939,
#  'colocated_variants': [{'strand': 1,
#    'frequencies': {'-': {'sas': 0,
#      'afr': 0.0333,
#      'amr': 0.0043,
#      'eur': 0,
#      'eas': 0}},
#    'minor_allele_freq': 0.0094,
#    'start': 23353939,
#    'minor_allele': '-',
#    'allele_string': 'C/-',
#    'seq_region_name': '13',
#    'end': 23353939,
#    'id': 'rs113268445'}]}

# %%
# move through the results
for variant in post_vep:
    
    # get the data
    input = variant['input']
    colocated_list = []
    for colocated in variant['colocated_variants']:
        colocated_list.append(colocated['id'])  
    print (input + ": " + (', '.join(colocated_list)))
